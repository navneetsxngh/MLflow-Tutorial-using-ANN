# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check Localhost Connector")
with mlflow.start_run():
    mlflow.log_metric("test", 1)
# Out:
# 2026/04/24 15:13:12 INFO mlflow.tracking.fluent: Experiment with name 'Check Localhost Connector' does not exist. Creating a new experiment.
# 🏃 View run adorable-fawn-288 at: http://127.0.0.1:5000/#/experiments/1/runs/ae0bae4d434f4e8c9ebb052437ed16bc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
